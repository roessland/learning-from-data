# %% [markdown]
# # Learning From Data HW 3

# %% [markdown]
# https://work.caltech.edu/homework/hw3.pdf

# %% [markdown]
# # 1, 2, 3: Generalization Error

# %%
import numpy as np

def computeN(eps, M, prob):
    return - np.log(prob/(2*M))/(2*eps**2)

print("1: ", computeN(0.05, 1, 0.03))
print("2: ", computeN(0.05, 10, 0.03))
print("3: ", computeN(0.05, 100, 0.03))
# Out:
# 1:  839.9410155759853
# 2:  1300.4580341747942
# 3:  1760.9750527736032

# %% [markdown]
# 1: Alternative B
#
# 2: Alternative C
#
# 3: Alternative D

# %% [markdown]
# # 4: Break Point

# %% [markdown]
# What is the break point for a 3D perceptron model?

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D



fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter([2, 2, 3], [1, 2, 0], [1, 3, 3], color="blue")
ax.scatter([1, 4], [-1, 4], [2, 2], color="red")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# The above data set is impossible to classify with a perceptron.
# (Three blue points form a triangle. Two red points form a line through the triangle.)
# So the break point is k=5.

# %% [markdown]
# # 5: Growth function

# %% [markdown]
# Illegal growth functions:
#
# * $2^{floor(N/2)}$ -- since all exponential growth functions must be $2^N$ (why though?)
#
# * $\sum_{i=1}^{floor(\sqrt N} {N\choose i}$ -- since it is above polynomial. (sum upper bound must be fixed, cannot depend on N). variable maximum power depending on N.
#
# Growth functions must be either polynomial in  $N$ with max degree $k$ or less, or $2^N$.
#
# Leaves alternative B.

# %% [markdown]
# # 6: Fun with Intervals

# %% [markdown]
# Consider y = [1, -1, 1, -1, 1]

# %% [markdown]
# It is impossible to model with two contiguous intervals, since three intervals are needed.
# Break point is thus $k=5$
#
# Alternative C.

# %% [markdown]
# # 7

# %% [markdown]
# Number of dichotomies for 2-intervals hypothesis set.

# %% [markdown]
# N=3: 2^3 = 8

# %%
from scipy.special import comb as choose

def alt_a(N):
    return choose(N+1, 4)

def alt_b(N):
    return choose(N+1, 2) + 1

def alt_c(N):
    return choose(N+1, 4) + choose(N+1, 2) + 1

def alt_d(N):
    return choose(N+1, 4) + choose(N+1, 3) + choose(N+1, 2) + choose(N+1, 1) + 1

# %%
print("\nA")
for i in range(1, 7):
    print(i, alt_a(i))

print("\nB")    
for i in range(1, 7):
    print(i, alt_b(i))

print("\nC")    
for i in range(1, 7):
    print(i, alt_c(i))
    
print("\nD")    
for i in range(1, 7):
    print(i, alt_d(i))
    
    
print("\nComputed by hand")
print("1 2.0")
print("2 4.0")
print("3 8.0")
print("4 16.0")
print("5 31.0")
print("6 57.0 (64 - 7)")
# Out:
# A
# 1 0.0
# 2 0.0
# 3 1.0
# 4 5.0
# 5 15.0
# 6 35.0
#
# B
# 1 2.0
# 2 4.0
# 3 7.0
# 4 11.0
# 5 16.0
# 6 22.0
#
# C
# 1 2.0
# 2 4.0
# 3 8.0
# 4 16.0
# 5 31.0
# 6 57.0
#
# D
# 1 4.0
# 2 8.0
# 3 16.0
# 4 31.0
# 5 57.0
# 6 99.0
#
# Computed by hand
# 1 2.0
# 2 4.0
# 3 8.0
# 4 16.0
# 5 31.0
# 6 57.0 (64 - 7)

# %% [markdown]
# So the only alternatives left are C and "none of the above".

# %% [markdown]
# Reasoning for C:
#
# Number of ways to choose two non-overlapping intervals
#
# plus
#
# Number of ways to choose one interval
#
# plus 1 for nothing being selected.

# %% [markdown]
# # 8

# %% [markdown]
# M-intervals learning model, what is the smallest break point?

# %% [markdown]
# See-saw configuration with 9 points is impossible to model with 4 intervals, since 5 intervals are needed. Thus breakpoint is 2M+1.

# %% [markdown]
# # 9: Convex sets: The Triangle

# %% [markdown]
# "Triangle learning model", +1 if inside triangle, -1 otherwise.

# %% [markdown]
# Arrange the points on the unit circle.
#
# For N=7 we can select any combination of points.
#
# For N=9 this becomes impossible since we get 4 "intervals" on the circle in zigzag configuration,
# but a triangle can only capture 3 intervals.
#
# So N=7 is shattered by H.

# %% [markdown]
# # 10: Non-Convex Sets: Concentric Circles

# %% [markdown]
# Arrange all points on a line.
#
# A concentric circle is then equivalent to choosing an interval + the case where nothing is chosen.
#
# (N+1 choose 2) + 1.
#
# Alternative B.
